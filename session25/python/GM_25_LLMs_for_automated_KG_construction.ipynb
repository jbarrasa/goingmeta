# %% [markdown]
# <a href="https://colab.research.google.com/github/jbarrasa/goingmeta/blob/main/session25/python/GM_25_LLMs_for_automated_KG_construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neo4j openai pandas rdflib-neo4j

# %%
import os, time
from pprint import pprint
from google.colab import userdata

os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
os.environ['NEO4J_URL'] = userdata.get('NEO4J_URL')
os.environ['NEO4J_USR'] = userdata.get('NEO4J_USR')
os.environ['NEO4J_PWD'] = userdata.get('NEO4J_PWD')

url = os.environ['NEO4J_URL']
username = os.environ['NEO4J_USR']
password = os.environ['NEO4J_PWD']

# %% [markdown]
# #Explore the croissant metadata (it's JSON-LD)

# %%
# croassant_file_path = 'https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/croissants/metadata-nyhousing.json'
# data_file_path = 'https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/NY-House-Dataset.csv'

croassant_file_path = 'https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/croissants/metadata-supplychain.json'
data_file_path = 'https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv'

# %%
from rdflib_neo4j import Neo4jStoreConfig, Neo4jStore, HANDLE_VOCAB_URI_STRATEGY
from rdflib import Graph

auth_data = {'uri': url,
             'database': "neo4j",
             'user': username,
             'pwd': password}

config = Neo4jStoreConfig(auth_data=auth_data,
                          handle_vocab_uri_strategy=HANDLE_VOCAB_URI_STRATEGY.IGNORE,
                          batching=True)

graph_store = Graph(store=Neo4jStore(config=config))

#temporary hack to parse JSON-LD until new version of rdflib-neo4j released
temp = Graph()
temp.parse(croassant_file_path, format="json-ld")

graph_store.parse(data=temp.serialize(format="ttl"), format="ttl")
graph_store.close(True)
# Out:
# Uniqueness constraint on :Resource(uri) is created.
# IMPORTED 288 TRIPLES

# %% [markdown]
# # Explore the metadata graph
#
# ```
# match graph = (:Dataset)-[:recordSet]->(:RecordSet)-[:field]->(:Field)-[:dataType]->()
# return graph
# ```

# %% [markdown]
# # Get a textual description to use when prompting the LLM

# %%
from neo4j import GraphDatabase

with GraphDatabase.driver(url, auth=(username, password)) as driver:
    driver.verify_connectivity()

    features_query = """
    match (d:Dataset)-[:recordSet]->(rs:RecordSet)-[:field]->(f:Field)-[:dataType]->(dt),
          (f)-[:source]->()-[:extract]->(e)
    return d.name as datasetname, d.description as datasetdescription,
           collect ({featurename : e.column, datatype : dt.uri }) as datasetfeatures
    """
    records, summary, keys = driver.execute_query(features_query)

    result = records[0]

    ds_name = result['datasetname']
    ds_description = result['datasetdescription']
    ds_features = result['datasetfeatures']

# %% [markdown]
# # Prompt creation

# %%
system = "You are a data modelling expert capable of creating high quality entity-relationship models from flat datasets"

prompt=f"""

From the list of features in the following dataset create a list of entities and relationships with their
attributes in a simple json format and map them to the features in the dataset.

The attributes don't need to be named after the features in the dataset, but they should be mapped to the corresponding feature name.
No extra text or comments, only the json as output.

DATASET NAME: {ds_name}

DATASET DESCRIPTION: {ds_description}

DATASET FEATURES: {ds_features}
"""

print(prompt)
# Out:
# From the list of features in the following dataset create a list of entities and relationships with their
# attributes in a simple json format and map them to the features in the dataset.
#
# The attributes don't need to be named after the features in the dataset, but they should be mapped to the corresponding feature name.
# No extra text or comments, only the json as output.
#
# DATASET NAME: Supply-Chain-Shipment-Pricing-Data
#
# DATASET DESCRIPTION: This data set provides supply chain health commodity shipment and pricing data.
#
# DATASET FEATURES: [{'featurename': 'Delivered to Client Date', 'datatype': 'https://schema.org/Date'}, {'featurename': 'Molecule/Test Type', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Dosage', 'datatype': 'https://schema.org/Text'}, {'featurename': 'ASN/DN #', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Line Item Quantity', 'datatype': 'https://schema.org/Integer'}, {'featurename': 'Brand', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Manufacturing Site', 'datatype': 'https://schema.org/Text'}, {'featurename': 'ID', 'datatype': 'https://schema.org/Text'}, {'featurename': 'PO Sent to Vendor Date', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Item Description', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Dosage Form', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Vendor INCO Term', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Sub Classification', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Managed By', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Scheduled Delivery Date', 'datatype': 'https://schema.org/Date'}, {'featurename': 'Product Group', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Line Item Insurance (USD)', 'datatype': 'https://schema.org/Float'}, {'featurename': 'Unit of Measure (Per Pack)', 'datatype': 'https://schema.org/Integer'}, {'featurename': 'Project Code', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Unit Price', 'datatype': 'https://schema.org/Float'}, {'featurename': 'Weight (Kilograms)', 'datatype': 'https://schema.org/Text'}, {'featurename': 'First Line Designation', 'datatype': 'https://schema.org/Boolean'}, {'featurename': 'Vendor', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Pack Price', 'datatype': 'https://schema.org/Float'}, {'featurename': 'PQ #', 'datatype': 'https://schema.org/Text'}, {'featurename': 'PO / SO #', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Delivery Recorded Date', 'datatype': 'https://schema.org/Date'}, {'featurename': 'Line Item Value', 'datatype': 'https://schema.org/Float'}, {'featurename': 'PQ First Sent to Client Date', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Freight Cost (USD)', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Country', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Shipment Mode', 'datatype': 'https://schema.org/Text'}, {'featurename': 'Fulfill Via', 'datatype': 'https://schema.org/Text'}]

# %% [markdown]
# # Call the completions API

# %%
from openai import OpenAI

client = OpenAI()
completion = client.chat.completions.create(model="gpt-4",
                                                  temperature=0,
        messages=[
            {"role": "system", "content": system},
            {"role": "user", "content": prompt},
        ])

# %%
genschema = completion.choices[0].message.content
print(genschema)
# Out:
# {
#   "entities": [
#     {
#       "name": "Shipment",
#       "attributes": [
#         {"name": "ShipmentID", "type": "https://schema.org/Text", "mappedTo": "ID"},
#         {"name": "DeliveryDate", "type": "https://schema.org/Date", "mappedTo": "Delivered to Client Date"},
#         {"name": "ScheduledDeliveryDate", "type": "https://schema.org/Date", "mappedTo": "Scheduled Delivery Date"},
#         {"name": "RecordedDeliveryDate", "type": "https://schema.org/Date", "mappedTo": "Delivery Recorded Date"},
#         {"name": "ShipmentMode", "type": "https://schema.org/Text", "mappedTo": "Shipment Mode"},
#         {"name": "FulfillVia", "type": "https://schema.org/Text", "mappedTo": "Fulfill Via"},
#         {"name": "FreightCost", "type": "https://schema.org/Text", "mappedTo": "Freight Cost (USD)"}
#       ]
#     },
#     {
#       "name": "Product",
#       "attributes": [
#         {"name": "ProductName", "type": "https://schema.org/Text", "mappedTo": "Item Description"},
#         {"name": "Brand", "type": "https://schema.org/Text", "mappedTo": "Brand"},
#         {"name": "Dosage", "type": "https://schema.org/Text", "mappedTo": "Dosage"},
#         {"name": "DosageForm", "type": "https://schema.org/Text", "mappedTo": "Dosage Form"},
#         {"name": "MoleculeTestType", "type": "https://schema.org/Text", "mappedTo": "Molecule/Test Type"},
#         {"name": "SubClassification", "type": "https://schema.org/Text", "mappedTo": "Sub Classification"},
#         {"name": "FirstLineDesignation", "type": "https://schema.org/Boolean", "mappedTo": "First Line Designation"},
#         {"name": "ProductGroup", "type": "https://schema.org/Text", "mappedTo": "Product Group"}
#       ]
#     },
#     {
#       "name": "Vendor",
#       "attributes": [
#         {"name": "VendorName", "type": "https://schema.org/Text", "mappedTo": "Vendor"},
#         {"name": "VendorINCOTerm", "type": "https://schema.org/Text", "mappedTo": "Vendor INCO Term"}
#       ]
#     },
#     {
#       "name": "Order",
#       "attributes": [
#         {"name": "OrderNumber", "type": "https://schema.org/Text", "mappedTo": "PO / SO #"},
#         {"name": "OrderSentDate", "type": "https://schema.org/Text", "mappedTo": "PO Sent to Vendor Date"},
#         {"name": "ProjectCode", "type": "https://schema.org/Text", "mappedTo": "Project Code"},
#         {"name": "ManagedBy", "type": "https://schema.org/Text", "mappedTo": "Managed By"}
#       ]
#     },
#     {
#       "name": "LineItem",
#       "attributes": [
#         {"name": "LineItemNumber", "type": "https://schema.org/Text", "mappedTo": "ASN/DN #"},
#         {"name": "Quantity", "type": "https://schema.org/Integer", "mappedTo": "Line Item Quantity"},
#         {"name": "UnitOfMeasure", "type": "https://schema.org/Integer", "mappedTo": "Unit of Measure (Per Pack)"},
#         {"name": "UnitPrice", "type": "https://schema.org/Float", "mappedTo": "Unit Price"},
#         {"name": "PackPrice", "type": "https://schema.org/Float", "mappedTo": "Pack Price"},
#         {"name": "LineItemValue", "type": "https://schema.org/Float", "mappedTo": "Line Item Value"},
#         {"name": "Insurance", "type": "https://schema.org/Float", "mappedTo": "Line Item Insurance (USD)"},
#         {"name": "Weight", "type": "https://schema.org/Text", "mappedTo": "Weight (Kilograms)"}
#       ]
#     },
#     {
#       "name": "ManufacturingSite",
#       "attributes": [
#         {"name": "SiteName", "type": "https://schema.org/Text", "mappedTo": "Manufacturing Site"}
#       ]
#     },
#     {
#       "name": "Country",
#       "attributes": [
#         {"name": "CountryName", "type": "https://schema.org/Text", "mappedTo": "Country"}
#       ]
#     }
#   ],
#   "relationships": [
#     {"from": "Shipment", "to": "Product", "type": "contains"},
#     {"from": "Shipment", "to": "Vendor", "type": "sent_by"},
#     {"from": "Shipment", "to": "Order", "type": "fulfills"},
#     {"from": "Shipment", "to": "LineItem", "type": "has"},
#     {"from": "Shipment", "to": "ManufacturingSite", "type": "originates_from"},
#     {"from": "Shipment", "to": "Country", "type": "delivered_to"},
#     {"from": "Product", "to": "LineItem", "type": "is_part_of"},
#     {"from": "Order", "to": "LineItem", "type": "contains"}
#   ]
# }

# %% [markdown]
# # Data import script generators (generic)

# %%
# adjust based on the JSON generated by the LLM
# there are beter (and more robust) ways to do this ;-)

e_name = "name"
a_name = "name"
map_att = "mappedTo"
r_name = "type"
r_from = "from"
r_to = "to"


def getIdValExprFor(sch, ename):
  result = []
  for x in sch["entities"]:
    if x[e_name] == ename:
      for y in x["attributes"]:
        result.append("toString(record.`" + y[map_att] + "`)")
  return " apoc.hashing.fingerprint( " + " + ".join(result) + " )"



def generateImportScript(sch):

  constraints = {}
  cypher_import = {}

  for e in sch["entities"]:
      constraints[e[e_name]] = "CREATE CONSTRAINT IF NOT EXISTS FOR (n:" + e[e_name] + ") REQUIRE n._id IS UNIQUE; "
      cypher = []
      cypher.append("unwind $records AS record")
      cypher.append("merge (n:`" + e[e_name] + "` { _id: " +  getIdValExprFor(sch, e[e_name]) + "} )")
      for p in e["attributes"]:
        propName = p[a_name]
        #type conversion ?
        #propType = p["datatype"]
        cypher.append("set n.`" + propName + "` = record.`" + p[map_att] + "`")
      cypher.append("return count(*) as total ;")
      cypher_import[e[e_name]] = ' \n'.join(cypher)

  for r in sch["relationships"]:
    cypher = []
    cypher.append("unwind $records AS record")
    cypher.append("match (source:" + r[r_from] + " { _id : " + getIdValExprFor(sch, r[r_from]) + "} )")
    cypher.append("match (target:" + r[r_to] + " { _id : " + getIdValExprFor(sch, r[r_to]) + "} )")
    cypher.append("merge (source)-[r:`"+ r[r_name] +"`]->(target)")
    cypher.append("return count(*) as total")
    cypher_import[r[r_name]] = ' \n'.join(cypher)

  return cypher_import , constraints

# %% [markdown]
# # Run the script generators on the model+mapping produced by the LLM

# %%
cypher_import, constraints = generateImportScript(eval(genschema))

# %%
print("\n\n#CONSTRAINTS:\n")
for q in constraints.keys():
  print(q + ": \n"+ constraints[q] + "\n")

print("#\n\nLOADERS:\n")
for q in cypher_import.keys():
  print(q + ": \n\nfile: " + data_file_path + "\n\n"+ cypher_import[q] + "\n\n")
# Out:
# #CONSTRAINTS:
#
# Shipment:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Shipment) REQUIRE n._id IS UNIQUE;
#
# Product:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Product) REQUIRE n._id IS UNIQUE;
#
# Vendor:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Vendor) REQUIRE n._id IS UNIQUE;
#
# Order:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Order) REQUIRE n._id IS UNIQUE;
#
# LineItem:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:LineItem) REQUIRE n._id IS UNIQUE;
#
# ManufacturingSite:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:ManufacturingSite) REQUIRE n._id IS UNIQUE;
#
# Country:
# CREATE CONSTRAINT IF NOT EXISTS FOR (n:Country) REQUIRE n._id IS UNIQUE;
#
# #
#
# LOADERS:
#
# Shipment:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`Shipment` { _id:  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# set n.`ShipmentID` = record.`ID`
# set n.`DeliveryDate` = record.`Delivered to Client Date`
# set n.`ScheduledDeliveryDate` = record.`Scheduled Delivery Date`
# set n.`RecordedDeliveryDate` = record.`Delivery Recorded Date`
# set n.`ShipmentMode` = record.`Shipment Mode`
# set n.`FulfillVia` = record.`Fulfill Via`
# set n.`FreightCost` = record.`Freight Cost (USD)`
# return count(*) as total ;
#
#
# Product:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`Product` { _id:  apoc.hashing.fingerprint( toString(record.`Item Description`) + toString(record.`Brand`) + toString(record.`Dosage`) + toString(record.`Dosage Form`) + toString(record.`Molecule/Test Type`) + toString(record.`Sub Classification`) + toString(record.`First Line Designation`) + toString(record.`Product Group`) )} )
# set n.`ProductName` = record.`Item Description`
# set n.`Brand` = record.`Brand`
# set n.`Dosage` = record.`Dosage`
# set n.`DosageForm` = record.`Dosage Form`
# set n.`MoleculeTestType` = record.`Molecule/Test Type`
# set n.`SubClassification` = record.`Sub Classification`
# set n.`FirstLineDesignation` = record.`First Line Designation`
# set n.`ProductGroup` = record.`Product Group`
# return count(*) as total ;
#
#
# Vendor:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`Vendor` { _id:  apoc.hashing.fingerprint( toString(record.`Vendor`) + toString(record.`Vendor INCO Term`) )} )
# set n.`VendorName` = record.`Vendor`
# set n.`VendorINCOTerm` = record.`Vendor INCO Term`
# return count(*) as total ;
#
#
# Order:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`Order` { _id:  apoc.hashing.fingerprint( toString(record.`PO / SO #`) + toString(record.`PO Sent to Vendor Date`) + toString(record.`Project Code`) + toString(record.`Managed By`) )} )
# set n.`OrderNumber` = record.`PO / SO #`
# set n.`OrderSentDate` = record.`PO Sent to Vendor Date`
# set n.`ProjectCode` = record.`Project Code`
# set n.`ManagedBy` = record.`Managed By`
# return count(*) as total ;
#
#
# LineItem:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`LineItem` { _id:  apoc.hashing.fingerprint( toString(record.`ASN/DN #`) + toString(record.`Line Item Quantity`) + toString(record.`Unit of Measure (Per Pack)`) + toString(record.`Unit Price`) + toString(record.`Pack Price`) + toString(record.`Line Item Value`) + toString(record.`Line Item Insurance (USD)`) + toString(record.`Weight (Kilograms)`) )} )
# set n.`LineItemNumber` = record.`ASN/DN #`
# set n.`Quantity` = record.`Line Item Quantity`
# set n.`UnitOfMeasure` = record.`Unit of Measure (Per Pack)`
# set n.`UnitPrice` = record.`Unit Price`
# set n.`PackPrice` = record.`Pack Price`
# set n.`LineItemValue` = record.`Line Item Value`
# set n.`Insurance` = record.`Line Item Insurance (USD)`
# set n.`Weight` = record.`Weight (Kilograms)`
# return count(*) as total ;
#
#
# ManufacturingSite:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`ManufacturingSite` { _id:  apoc.hashing.fingerprint( toString(record.`Manufacturing Site`) )} )
# set n.`SiteName` = record.`Manufacturing Site`
# return count(*) as total ;
#
#
# Country:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# merge (n:`Country` { _id:  apoc.hashing.fingerprint( toString(record.`Country`) )} )
# set n.`CountryName` = record.`Country`
# return count(*) as total ;
#
#
# contains:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Order { _id :  apoc.hashing.fingerprint( toString(record.`PO / SO #`) + toString(record.`PO Sent to Vendor Date`) + toString(record.`Project Code`) + toString(record.`Managed By`) )} )
# match (target:LineItem { _id :  apoc.hashing.fingerprint( toString(record.`ASN/DN #`) + toString(record.`Line Item Quantity`) + toString(record.`Unit of Measure (Per Pack)`) + toString(record.`Unit Price`) + toString(record.`Pack Price`) + toString(record.`Line Item Value`) + toString(record.`Line Item Insurance (USD)`) + toString(record.`Weight (Kilograms)`) )} )
# merge (source)-[r:`contains`]->(target)
# return count(*) as total
#
#
# sent_by:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Shipment { _id :  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# match (target:Vendor { _id :  apoc.hashing.fingerprint( toString(record.`Vendor`) + toString(record.`Vendor INCO Term`) )} )
# merge (source)-[r:`sent_by`]->(target)
# return count(*) as total
#
#
# fulfills:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Shipment { _id :  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# match (target:Order { _id :  apoc.hashing.fingerprint( toString(record.`PO / SO #`) + toString(record.`PO Sent to Vendor Date`) + toString(record.`Project Code`) + toString(record.`Managed By`) )} )
# merge (source)-[r:`fulfills`]->(target)
# return count(*) as total
#
#
# has:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Shipment { _id :  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# match (target:LineItem { _id :  apoc.hashing.fingerprint( toString(record.`ASN/DN #`) + toString(record.`Line Item Quantity`) + toString(record.`Unit of Measure (Per Pack)`) + toString(record.`Unit Price`) + toString(record.`Pack Price`) + toString(record.`Line Item Value`) + toString(record.`Line Item Insurance (USD)`) + toString(record.`Weight (Kilograms)`) )} )
# merge (source)-[r:`has`]->(target)
# return count(*) as total
#
#
# originates_from:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Shipment { _id :  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# match (target:ManufacturingSite { _id :  apoc.hashing.fingerprint( toString(record.`Manufacturing Site`) )} )
# merge (source)-[r:`originates_from`]->(target)
# return count(*) as total
#
#
# delivered_to:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Shipment { _id :  apoc.hashing.fingerprint( toString(record.`ID`) + toString(record.`Delivered to Client Date`) + toString(record.`Scheduled Delivery Date`) + toString(record.`Delivery Recorded Date`) + toString(record.`Shipment Mode`) + toString(record.`Fulfill Via`) + toString(record.`Freight Cost (USD)`) )} )
# match (target:Country { _id :  apoc.hashing.fingerprint( toString(record.`Country`) )} )
# merge (source)-[r:`delivered_to`]->(target)
# return count(*) as total
#
#
# is_part_of:
#
# file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
#
# unwind $records AS record
# match (source:Product { _id :  apoc.hashing.fingerprint( toString(record.`Item Description`) + toString(record.`Brand`) + toString(record.`Dosage`) + toString(record.`Dosage Form`) + toString(record.`Molecule/Test Type`) + toString(record.`Sub Classification`) + toString(record.`First Line Designation`) + toString(record.`Product Group`) )} )
# match (target:LineItem { _id :  apoc.hashing.fingerprint( toString(record.`ASN/DN #`) + toString(record.`Line Item Quantity`) + toString(record.`Unit of Measure (Per Pack)`) + toString(record.`Unit Price`) + toString(record.`Pack Price`) + toString(record.`Line Item Value`) + toString(record.`Line Item Insurance (USD)`) + toString(record.`Weight (Kilograms)`) )} )
# merge (source)-[r:`is_part_of`]->(target)
# return count(*) as total

# %% [markdown]
# # Run the actual import into the Neo4j DB

# %%
# Utility function to write to Neo4j in batch mode.

def insert_data(session, query, frame, batch_size = 500):

    total = 0
    batch = 0
    start = time.time()
    result = None

    while batch * batch_size < len(frame):
        res = session.execute_write( lambda tx: tx.run(query,
                      parameters = {'records': frame[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data())

        total += res[0]['total']
        batch += 1
        result = {"total":total,
                  "batches":batch,
                  "time":time.time()-start}
        print(result)

    return result

# %%
import pandas as pd
from neo4j import GraphDatabase, basic_auth


with GraphDatabase.driver(url, auth=(username, password)) as driver:
    driver.verify_connectivity()

    for c in constraints.keys():
      driver.execute_query(constraints[c])

    session = driver.session(database="neo4j")
    print("Source file: " + data_file_path)
    for q in cypher_import.keys():
      print("importing " + q )
      df = pd.read_csv(data_file_path, encoding = "ISO-8859-1")
      result = insert_data(session, cypher_import[q], df, batch_size = 1000)
      print(result)
# Out:
# Source file: https://raw.githubusercontent.com/jbarrasa/goingmeta/main/session25/resources/csvs/SCMS_Delivery_History_Dataset_20150929.csv
# importing Shipment
# {'total': 1000, 'batches': 1, 'time': 1.6937587261199951}
# {'total': 2000, 'batches': 2, 'time': 2.5980336666107178}
# {'total': 3000, 'batches': 3, 'time': 3.485304117202759}
# {'total': 4000, 'batches': 4, 'time': 4.4452738761901855}
# {'total': 5000, 'batches': 5, 'time': 5.379028797149658}
# {'total': 6000, 'batches': 6, 'time': 6.204134941101074}
# {'total': 7000, 'batches': 7, 'time': 6.9337639808654785}
# {'total': 8000, 'batches': 8, 'time': 7.649659872055054}
# {'total': 9000, 'batches': 9, 'time': 8.345618486404419}
# {'total': 10000, 'batches': 10, 'time': 9.052983522415161}
# {'total': 10324, 'batches': 11, 'time': 9.592599630355835}
# {'total': 10324, 'batches': 11, 'time': 9.592599630355835}
# importing Product
# {'total': 1000, 'batches': 1, 'time': 1.0460126399993896}
# {'total': 2000, 'batches': 2, 'time': 1.7030611038208008}
# {'total': 3000, 'batches': 3, 'time': 2.3533239364624023}
# {'total': 4000, 'batches': 4, 'time': 2.9995198249816895}
# {'total': 5000, 'batches': 5, 'time': 3.6477596759796143}
# {'total': 6000, 'batches': 6, 'time': 4.287368535995483}
# {'total': 7000, 'batches': 7, 'time': 4.918543815612793}
# {'total': 8000, 'batches': 8, 'time': 5.629319429397583}
# {'total': 9000, 'batches': 9, 'time': 6.503162622451782}
# {'total': 10000, 'batches': 10, 'time': 7.159581422805786}
# {'total': 10324, 'batches': 11, 'time': 7.6755359172821045}
# {'total': 10324, 'batches': 11, 'time': 7.6755359172821045}
# importing Vendor
# {'total': 1000, 'batches': 1, 'time': 0.7411415576934814}
# {'total': 2000, 'batches': 2, 'time': 1.353893756866455}
# {'total': 3000, 'batches': 3, 'time': 1.973801612854004}
# {'total': 4000, 'batches': 4, 'time': 2.6087632179260254}
# {'total': 5000, 'batches': 5, 'time': 3.3411340713500977}
# {'total': 6000, 'batches': 6, 'time': 3.9638805389404297}
# {'total': 7000, 'batches': 7, 'time': 4.5860419273376465}
# {'total': 8000, 'batches': 8, 'time': 5.229117155075073}
# {'total': 9000, 'batches': 9, 'time': 5.858856678009033}
# {'total': 10000, 'batches': 10, 'time': 6.473559379577637}
# {'total': 10324, 'batches': 11, 'time': 6.956144571304321}
# {'total': 10324, 'batches': 11, 'time': 6.956144571304321}
# importing Order
# {'total': 1000, 'batches': 1, 'time': 0.8215508460998535}
# {'total': 2000, 'batches': 2, 'time': 1.4932756423950195}
# {'total': 3000, 'batches': 3, 'time': 2.315551280975342}
# {'total': 4000, 'batches': 4, 'time': 3.2282605171203613}
# {'total': 5000, 'batches': 5, 'time': 3.888838052749634}
# {'total': 6000, 'batches': 6, 'time': 4.573592901229858}
# {'total': 7000, 'batches': 7, 'time': 5.2349419593811035}
# {'total': 8000, 'batches': 8, 'time': 5.920176267623901}
# {'total': 9000, 'batches': 9, 'time': 6.740885496139526}
# {'total': 10000, 'batches': 10, 'time': 7.416848182678223}
# {'total': 10324, 'batches': 11, 'time': 7.8834288120269775}
# {'total': 10324, 'batches': 11, 'time': 7.8834288120269775}
# importing LineItem
# {'total': 1000, 'batches': 1, 'time': 0.857795238494873}
# {'total': 2000, 'batches': 2, 'time': 1.5540697574615479}
# {'total': 3000, 'batches': 3, 'time': 2.2401490211486816}
# {'total': 4000, 'batches': 4, 'time': 2.9524190425872803}
# {'total': 5000, 'batches': 5, 'time': 3.6604933738708496}
# {'total': 6000, 'batches': 6, 'time': 4.362339735031128}
# {'total': 7000, 'batches': 7, 'time': 5.061560392379761}
# {'total': 8000, 'batches': 8, 'time': 5.96177339553833}
# {'total': 9000, 'batches': 9, 'time': 6.84093451499939}
# {'total': 10000, 'batches': 10, 'time': 7.578299045562744}
# {'total': 10324, 'batches': 11, 'time': 8.105291843414307}
# {'total': 10324, 'batches': 11, 'time': 8.105291843414307}
# importing ManufacturingSite
# {'total': 1000, 'batches': 1, 'time': 0.7890818119049072}
# {'total': 2000, 'batches': 2, 'time': 1.411320686340332}
# {'total': 3000, 'batches': 3, 'time': 2.0251336097717285}
# {'total': 4000, 'batches': 4, 'time': 2.6669328212738037}
# {'total': 5000, 'batches': 5, 'time': 3.2847630977630615}
# {'total': 6000, 'batches': 6, 'time': 3.9869306087493896}
# {'total': 7000, 'batches': 7, 'time': 4.688892126083374}
# {'total': 8000, 'batches': 8, 'time': 5.302778244018555}
# {'total': 9000, 'batches': 9, 'time': 5.920796155929565}
# {'total': 10000, 'batches': 10, 'time': 6.533257007598877}
# {'total': 10324, 'batches': 11, 'time': 7.009197950363159}
# {'total': 10324, 'batches': 11, 'time': 7.009197950363159}
# importing Country
# {'total': 1000, 'batches': 1, 'time': 0.689558744430542}
# {'total': 2000, 'batches': 2, 'time': 1.2964222431182861}
# {'total': 3000, 'batches': 3, 'time': 2.0946314334869385}
# {'total': 4000, 'batches': 4, 'time': 2.8614673614501953}
# {'total': 5000, 'batches': 5, 'time': 3.491206169128418}
# {'total': 6000, 'batches': 6, 'time': 4.203131437301636}
# {'total': 7000, 'batches': 7, 'time': 4.813793659210205}
# {'total': 8000, 'batches': 8, 'time': 5.434076547622681}
# {'total': 9000, 'batches': 9, 'time': 6.05085015296936}
# {'total': 10000, 'batches': 10, 'time': 6.673192977905273}
# {'total': 10324, 'batches': 11, 'time': 7.152003049850464}
# {'total': 10324, 'batches': 11, 'time': 7.152003049850464}
# importing contains
# {'total': 1000, 'batches': 1, 'time': 1.2496669292449951}
# {'total': 2000, 'batches': 2, 'time': 1.9456143379211426}
# {'total': 3000, 'batches': 3, 'time': 2.6622204780578613}
# {'total': 4000, 'batches': 4, 'time': 3.359874963760376}
# {'total': 5000, 'batches': 5, 'time': 4.0610527992248535}
# {'total': 6000, 'batches': 6, 'time': 4.77302360534668}
# {'total': 7000, 'batches': 7, 'time': 5.466201066970825}
# {'total': 8000, 'batches': 8, 'time': 6.57115912437439}
# {'total': 9000, 'batches': 9, 'time': 7.364821910858154}
# {'total': 10000, 'batches': 10, 'time': 8.05757474899292}
# {'total': 10324, 'batches': 11, 'time': 8.531073093414307}
# {'total': 10324, 'batches': 11, 'time': 8.531073093414307}
# importing sent_by
# {'total': 1000, 'batches': 1, 'time': 0.8852295875549316}
# {'total': 2000, 'batches': 2, 'time': 1.5556325912475586}
# {'total': 3000, 'batches': 3, 'time': 2.2265727519989014}
# {'total': 4000, 'batches': 4, 'time': 2.917746067047119}
# {'total': 5000, 'batches': 5, 'time': 3.5802056789398193}
# {'total': 6000, 'batches': 6, 'time': 4.2652342319488525}
# {'total': 7000, 'batches': 7, 'time': 4.982219696044922}
# {'total': 8000, 'batches': 8, 'time': 5.6473565101623535}
# {'total': 9000, 'batches': 9, 'time': 6.328118801116943}
# {'total': 10000, 'batches': 10, 'time': 7.04270601272583}
# {'total': 10324, 'batches': 11, 'time': 7.567302227020264}
# {'total': 10324, 'batches': 11, 'time': 7.567302227020264}
# importing fulfills
# {'total': 1000, 'batches': 1, 'time': 1.0203824043273926}
# {'total': 2000, 'batches': 2, 'time': 1.9405877590179443}
# {'total': 3000, 'batches': 3, 'time': 2.6072921752929688}
# {'total': 4000, 'batches': 4, 'time': 3.2962703704833984}
# {'total': 5000, 'batches': 5, 'time': 3.9770541191101074}
# {'total': 6000, 'batches': 6, 'time': 4.657750606536865}
# {'total': 7000, 'batches': 7, 'time': 5.354602575302124}
# {'total': 8000, 'batches': 8, 'time': 6.030797719955444}
# {'total': 9000, 'batches': 9, 'time': 6.696735858917236}
# {'total': 10000, 'batches': 10, 'time': 7.39678692817688}
# {'total': 10324, 'batches': 11, 'time': 7.899848937988281}
# {'total': 10324, 'batches': 11, 'time': 7.899848937988281}
# importing has
# {'total': 1000, 'batches': 1, 'time': 0.8801455497741699}
# {'total': 2000, 'batches': 2, 'time': 1.5585031509399414}
# {'total': 3000, 'batches': 3, 'time': 2.2605643272399902}
# {'total': 4000, 'batches': 4, 'time': 2.938948154449463}
# {'total': 5000, 'batches': 5, 'time': 3.619654417037964}
# {'total': 6000, 'batches': 6, 'time': 4.601044416427612}
# {'total': 7000, 'batches': 7, 'time': 5.38972806930542}
# {'total': 8000, 'batches': 8, 'time': 6.095288515090942}
# {'total': 9000, 'batches': 9, 'time': 6.777815580368042}
# {'total': 10000, 'batches': 10, 'time': 7.465361833572388}
# {'total': 10324, 'batches': 11, 'time': 7.996826171875}
# {'total': 10324, 'batches': 11, 'time': 7.996826171875}
# importing originates_from
# {'total': 1000, 'batches': 1, 'time': 0.8601291179656982}
# {'total': 2000, 'batches': 2, 'time': 1.5320489406585693}
# {'total': 3000, 'batches': 3, 'time': 2.214446783065796}
# {'total': 4000, 'batches': 4, 'time': 2.8825137615203857}
# {'total': 5000, 'batches': 5, 'time': 3.578669786453247}
# {'total': 6000, 'batches': 6, 'time': 4.233618974685669}
# {'total': 7000, 'batches': 7, 'time': 4.9931464195251465}
# {'total': 8000, 'batches': 8, 'time': 5.657267332077026}
# {'total': 9000, 'batches': 9, 'time': 6.432041168212891}
# {'total': 10000, 'batches': 10, 'time': 7.09016489982605}
# {'total': 10324, 'batches': 11, 'time': 7.675153970718384}
# {'total': 10324, 'batches': 11, 'time': 7.675153970718384}
# importing delivered_to
# {'total': 1000, 'batches': 1, 'time': 0.8756735324859619}
# {'total': 2000, 'batches': 2, 'time': 1.5561647415161133}
# {'total': 3000, 'batches': 3, 'time': 2.217979907989502}
# {'total': 4000, 'batches': 4, 'time': 2.906026601791382}
# {'total': 5000, 'batches': 5, 'time': 3.5885844230651855}
# {'total': 6000, 'batches': 6, 'time': 4.271477699279785}
# {'total': 7000, 'batches': 7, 'time': 4.941080093383789}
# {'total': 8000, 'batches': 8, 'time': 5.60397481918335}
# {'total': 9000, 'batches': 9, 'time': 6.273662090301514}
# {'total': 10000, 'batches': 10, 'time': 6.955374002456665}
# {'total': 10324, 'batches': 11, 'time': 7.462411880493164}
# {'total': 10324, 'batches': 11, 'time': 7.462411880493164}
# importing is_part_of
# {'total': 1000, 'batches': 1, 'time': 1.0194599628448486}
# {'total': 2000, 'batches': 2, 'time': 1.7927250862121582}
# {'total': 3000, 'batches': 3, 'time': 2.4684512615203857}
# {'total': 4000, 'batches': 4, 'time': 3.3272221088409424}
# {'total': 5000, 'batches': 5, 'time': 4.185549259185791}
# {'total': 6000, 'batches': 6, 'time': 4.850602149963379}
# {'total': 7000, 'batches': 7, 'time': 5.5371253490448}
# {'total': 8000, 'batches': 8, 'time': 6.239590883255005}
# {'total': 9000, 'batches': 9, 'time': 6.952905654907227}
# {'total': 10000, 'batches': 10, 'time': 7.641578435897827}
# {'total': 10324, 'batches': 11, 'time': 8.175037860870361}
# {'total': 10324, 'batches': 11, 'time': 8.175037860870361}
